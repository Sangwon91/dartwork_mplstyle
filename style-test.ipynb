# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
mpl.style.use('./dartwork.mplstyle')

# %%
x = np.linspace(0, 2*np.pi, 300)
cosx = np.cos(x)
sinx = np.sin(x)

plt.plot(x, cosx, label='Cosine')
plt.plot(x, sinx, label='Sine')
plt.plot(x, cosx**2, label='Cosine^2')
plt.plot(x, sinx**2, label='Sine^2')
plt.legend()
